# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import *
# %matplotlib inline

# %%
x = pd.read_csv("dist.csv")

# %%
n1=x["n1"]
n2=x["n2"]
data1= pd.DataFrame()

# %%
x1 = np.linspace(200,350,num=2000)
print n1.mean()
p=poisson(n1.mean())
p1=pd.Series(p.rvs(106))
fig.add_subplot("110")
p1.hist(bins=8,alpha=0.5,label="ideal poissonian")
n1.hist(bins = 30,color="r",alpha=0.5,label="experiment")
plt.legend(loc = 0)
plt.xlabel("photon number")
plt.ylabel("event number")
# Out:
# 275.276190476

# %%
print n2.mean()
p=poisson(n2.mean())
p2=pd.Series(p.rvs(len(n2)))
p2.hist(bins=10,alpha=0.5,label="ideal poissonian")
n2.hist(bins = 50,color="r",alpha=0.5,label="experiment")
plt.legend(loc = 0)
plt.xlabel("photon number")
plt.ylabel("event number")
# Out:
# 12797.6129032

# %%
plt.plot(np.histogram(n1,bins=np.linspace(200,350,30))[0])

# %%
norm.fit(n1)
# Out:
# (nan, nan)

# %%
for i in p.rvs(106):
    print i
# Out:
# 262
# 297
# 272
# 278
# 305
# 288
# 290
# 264
# 264
# 277
# 264
# 241
# 289
# 302
# 310
# 283
# 267
# 274
# 274
# 227
# 280
# 265
# 266
# 268
# 283
# 275
# 272
# 279
# 269
# 284
# 243
# 291
# 268
# 245
# 250
# 270
# 280
# 293
# 258
# 260
# 285
# 270
# 284
# 291
# 278
# 268
# 307
# 274
# 294
# 297
# 285
# 263
# 280
# 272
# 265
# 277
# 279
# 252
# 294
# 276
# 284
# 279
# 272
# 280
# 271
# 255
# 285
# 260
# 271
# 302
# 270
# 253
# 266
# 289
# 269
# 285
# 253
# 271
# 278
# 301
# 291
# 286
# 274
# 268
# 295
# 291
# 275
# 273
# 283
# 298
# 270
# 277
# 259
# 291
# 278
# 312
# 258
# 268
# 294
# 243
# 277
# 270
# 332
# 269
# 311
# 280

# %%
data1 = pd.DataFrame()
data1 = data1.append(n1)
data1 = data1.append(p1,ignore_index=True)
data1 = data1.T

# %%
data1
# Out:
#        0    1
# 0    306  285
# 1    284  294
# 2    272  292
# 3    264  287
# 4    286  251
# 5    278  264
# 6    231  271
# 7    245  292
# 8    284  255
# 9    310  264
# 10   262  279
# 11   291  293
# 12   275  278
# 13   230  280
# 14   247  263
# 15   263  270
# 16   250  259
# 17   258  285
# 18   223  265
# 19   256  249
# 20   239  266
# 21   278  272
# 22   253  297
# 23   269  300
# 24   257  266
# 25   271  288
# 26   267  293
# 27   232  256
# 28   279  248
# 29   281  282
# ..   ...  ...
# 125  NaN  277
# 126  NaN  247
# 127  NaN  236
# 128  NaN  259
# 129  NaN  275
# 130  NaN  259
# 131  NaN  274
# 132  NaN  257
# 133  NaN  262
# 134  NaN  275
# 135  NaN  268
# 136  NaN  274
# 137  NaN  302
# 138  NaN  263
# 139  NaN  293
# 140  NaN  238
# 141  NaN  247
# 142  NaN  269
# 143  NaN  280
# 144  NaN  273
# 145  NaN  280
# 146  NaN  274
# 147  NaN  296
# 148  NaN  300
# 149  NaN  287
# 150  NaN  277
# 151  NaN  292
# 152  NaN  293
# 153  NaN  252
# 154  NaN  268
#
# ...
