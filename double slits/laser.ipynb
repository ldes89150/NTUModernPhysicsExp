# %%
import pandas as pd

# %%
x = pd.read_csv("laser.csv")

# %%
x
# Out:
#      x(mm)  laserF(nV)  laserB(nV)  leftF(nV)  leftB(nV)  rightF(nV)  \
# 0      0.0          77          98         10         11          33
# 1      0.2          82          99         11         12          35
# 2      0.4          67          73         13         13          36
# 3      0.6          38          44         14         14          38
# 4      0.8          16          31         15         15          39
# 5      1.0          22          47         16         16          41
# 6      1.2          58          89         18         17          43
# 7      1.4         106         135         19         19          46
# 8      1.6         133         147         21         19          48
# 9      1.8         118         116         22         20          51
# 10     2.0          72          65         23         21          52
# 11     2.2          29          30         24         22          53
# 12     2.4          21          37         26         24          54
# ...
